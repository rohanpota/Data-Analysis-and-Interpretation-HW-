# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn

# %%
data = pd.read_csv('gapminder.csv', low_memory=False)

# %%
#setting variables I will be working with to numeric
data['incomeperperson'] = data['incomeperperson'].convert_objects(convert_numeric=True)
data['alcconsumption'] = data['alcconsumption'].convert_objects(convert_numeric=True)
data['co2emissions'] = data['co2emissions'].convert_objects(convert_numeric=True)
data['employrate'] = data['employrate'].convert_objects(convert_numeric=True)
data['suicideper100th'] = data['suicideper100th'].convert_objects(convert_numeric=True)
data['polityscore'] = data['polityscore'].convert_objects(convert_numeric=True)
data['lifeexpectancy'] = data['lifeexpectancy'].convert_objects(convert_numeric=True)
recode1 = {-10:0,-9:0.5,-8:1,-7:1.5,-6:2,-5:2.5,-4:3,-3:3.5,-2:4,-1:4.5,0:5,1:5.5,2:6,3:6.5,4:7,5:7.5,6:8,7:8.5,8:9,9:9.5,10:10}
data['polityscore']= data['polityscore'].map(recode1)
data['breastcancerper100th'] = data['breastcancerper100th'].convert_objects(convert_numeric=True)
data['hivrate'] = data['hivrate'].convert_objects(convert_numeric=True)
data['chthrate']=data['breastcancerper100th']+data['hivrate']

# %%
data=data.dropna()

# %%
ax=data['incomeperperson'].plot(kind='hist',bins=100)
ax.set_xlabel("Incomeperperson")
ax.set_ylabel("Frequency")

# %%
seaborn.distplot(data['alcconsumption'],hist=True,bins=100)
plt.xlabel('AlcoholConsumption')
plt.ylabel('Frequency(normalized 0->1)')

# %%
seaborn.distplot(data['incomeperperson'],hist=True,bins=100)
plt.xlabel('Income Per Person')
plt.ylabel('Frequency(normalized 0->1)')

# %%
seaborn.distplot(data['co2emissions'],hist=True,bins=200)
plt.xlabel('Co2 Emissions')
plt.ylabel('Frequency')

# %%
seaborn.distplot(data['employrate'],hist=True,bins=100)
plt.xlabel('Employment Rate')
plt.ylabel('Frequency(normalized 0->1)')

# %%
seaborn.distplot(data['suicideper100th'],hist=True,bins=100)
plt.xlabel('Suicide Per 100th')
plt.ylabel('Frequency(normalized 0->1)')

# %%
seaborn.distplot(data['polityscore'],hist=True,bins=200)
plt.xlabel('Polity Score')
plt.ylabel('Frequency')

# %%
seaborn.distplot(data['lifeexpectancy'],hist=True,bins=200)
plt.xlabel('Life Expectancy')
plt.ylabel('Frequency')

# %%
seaborn.distplot(data['chthrate'],hist=True,bins=200)
plt.xlabel('Criticial Health Rate')
plt.ylabel('Frequency')

# %%
scat1 = seaborn.regplot(x="incomeperperson", y="lifeexpectancy", fit_reg=True, data=data)
plt.xlabel('Income Per Person')
plt.ylabel('Life Expectancy')
plt.title('Scatterplot for the Association Between Income Per Person and Life Expectancy')

# %%
scat1 = seaborn.regplot(x="alcconsumption", y="lifeexpectancy", fit_reg=True, data=data)
plt.xlabel('Alcohol Consumption')
plt.ylabel('Life Expectancy')
plt.title('Scatterplot for the Association Between Alcohol Consumption and Life Expectancy')

# %%
scat1 = seaborn.regplot(x="co2emissions", y="lifeexpectancy", fit_reg=True, data=data)
plt.xlabel('CO2 Emissions')
plt.ylabel('Life Expectancy')
plt.title('Scatterplot for the Association Between CO2 Emissions and Life Expectancy')

# %%
scat1 = seaborn.regplot(x="employrate", y="lifeexpectancy", fit_reg=True, data=data)
plt.xlabel('Employement Rate')
plt.ylabel('Life Expectancy')
plt.title('Scatterplot for the Association Between Employement Rate and Life Expectancy')

# %%
scat1 = seaborn.regplot(x="suicideper100th", y="lifeexpectancy", fit_reg=True, data=data)
plt.xlabel('Suicide Per 100th')
plt.ylabel('Life Expectancy')
plt.title('Scatterplot for the Association Between Suicide Per 100th and Life Expectancy')

# %%
scat1 = seaborn.regplot(x="polityscore", y="lifeexpectancy", fit_reg=True, data=data)
plt.xlabel('Political Score')
plt.ylabel('Life Expectancy')
plt.title('Scatterplot for the Association Between Political Score and Life Expectancy')

# %%
scat1 = seaborn.regplot(x="chthrate", y="lifeexpectancy", fit_reg=True, data=data)
plt.xlabel('Critical Health Rate')
plt.ylabel('Life Expectancy')
plt.title('Scatterplot for the Association Between Critical Health Rate and Life Expectancy')
